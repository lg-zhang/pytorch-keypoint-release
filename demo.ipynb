# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cv2
import torch

from evaluation import KeypointDetector
from modules import KeypointNet
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = KeypointNet()
model.load_state_dict(torch.load("pretrained.pth"))
model = model.cuda()
key_det = KeypointDetector(model)

im_p = "/home/linguangzhang/projects/pytorch-keypoint/data/TILDE/carpet01_test/test/image_gray/image_00295.png"
im = cv2.imread(im_p, 0)
_, score_map = key_det(im, True, True)

# %%
plt.imshow(score_map, cmap="jet")
plt.show()
